# %% [markdown]
# # Template of  jupyter notebook for analysis of WAXS

# %% [markdown]
# # Load package

# %%
# %matplotlib notebook
from pyScatt.packages import *
plt.rcParams.update({'figure.max_open_warning': 0})
plt.rcParams.update({ 'image.origin': 'lower'   })
plt.rcParams.update({ 'image.interpolation': 'none'   })
# Out:
# WARNING:silx.opencl.common:The module pyOpenCL has been imported but can't be used here

# %%
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/Scattering.py

# %% [markdown]
# ## Define path

# %%
scat = 'WAXS'
det = '800K'

username = 'Dishari' 
cycle = '2020_Cycle3'
beamline = 'CMS'
 
#inDir = '/home/group/NSLSII_Data/CMS/2020_Cycle3/%s/saxs/raw/'%username
inDir ='/home/yuzhang/NSLSII_Data_Link/CMS/2020_Cycle3/%s/Results/Dishari/Results/Stitched/waxs/'%(username )
print('The input dir is: %s'%inDir)

outDir0_ = '/home/group/NSLSII_Data/CMS/2020_Cycle3/%s/Results/'%username
outDir0_ = create_fullpath(  outDir0_ )
outDir0 = create_fullpath(  outDir0_ + username + '/' )
print('The output dir is: %s'%outDir0)
# Out:
# The input dir is: /home/yuzhang/NSLSII_Data_Link/CMS/2020_Cycle3/Dishari/Results/Dishari/Results/Stitched/waxs/
# Directory  /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/  already exists
# Directory  /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/  already exists
# The output dir is: /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/

# %%
flag_save = True 

outDir1 = create_fullpath(  outDir0   + '%s/'%(scat)) 
outDir = create_dir(  'Results/', outDir1 )
create_dir( '%s/Results/TIFF/'%(scat), outDir0  )
outDir_HDF =  create_dir(  'HDF_Results/', outDir0 )
outDir_ResPipe = create_dir(  'ResPipes/', outDir1 )

print( outDir )
print( outDir_HDF)
print( outDir_ResPipe)
# Out:
# Directory  /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/  already exists
# Directory  /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/Results/  already exists
# Directory  /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/Results/TIFF/  already exists
# Directory  /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/HDF_Results/  already exists
# Directory  /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/ResPipes/  already exists
# /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/Results/
# /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/HDF_Results/
# /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/ResPipes/

# %% [markdown]
# # Find data

# %%
username_ = 'SD'

flists = ls_dir( inDir, and_list=[ username_ ])
Nf = len( flists)
print('There are %s files for user: %s in this run.'%(Nf, username))
# Out:
# There are 945 files for user: Dishari in this run.

# %%
9*3*5*7
# Out:
# 945

# %% [markdown]
# ## Find a sub-list

# %%
sam_dict, sams = get_Unique_SamDict_from_list( flists, cut_pattern= r'[_][p][o][s]', starting_point=0,     )   
ks =  sorted(list(sams.keys()))
N = len(ks)
print( 'There are %s samples.'%(N))
# Out:
# There are 27 samples.

# %%
sams
# Out:
# {'SD_Bare_Si_Wafer': 35,
#  'SD_C2_IEC2_Unannealed_117': 35,
#  'SD_C2_IEC2_Unannealed_20': 35,
#  'SD_C2_IEC2_Unannealed_55': 35,
#  'SD_C2_IEC3_Annealed_117': 35,
#  'SD_C2_IEC3_Annealed_20': 35,
#  'SD_C2_IEC3_Annealed_55': 35,
#  'SD_C2_IEC3_Annealed_70': 35,
#  'SD_C2_IEC4_Annealed_20': 35,
#  'SD_C2_IEC4_Annealed_50': 35,
#  'SD_C2_IEC4_Annealed_70': 35,
#  'SD_C2_IEC4_Annealed_90': 35,
#  'SD_C2_IEC4_Unannealed_20': 35,
#  'SD_C2_IEC4_Unannealed_50': 35,
#  'SD_C2_IEC4_Unannealed_90': 35,
#  'SD_Nafion_Annealed_115': 35,
#  'SD_Nafion_Annealed_17': 35,
#  'SD_Nafion_Annealed_46': 35,
#  'SD_Nafion_Annealed_70': 35,
#  'SD_PSC2_IEC2_Annealed_20': 35,
#  'SD_PSC2_IEC2_Annealed_52': 35,
#  'SD_PSC_IEC2_Annealed_118': 35,
#  'SD_PSC_IEC2_Annealed_70': 35,
#  'SD_PSC_IEC3p6_Annealed_100': 35,
#  'SD_PSC_IEC3p6_Annealed_20': 35,
#  'SD_PSC_IEC3p6_Annealed_50': 35,
#  'SD_PSC_IEC3p6_Annealed_70': 35}

# %% [markdown]
# # Test one data for sort

# %%
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/IO.py
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/generic_functions.py

# %%
i = 4
sam =  ks[i] 
print( sam )
flist  = sam_dict[ ks[i]]
sflistd = sort_fnlist( flist, pattern='', cut_beg = -24, cut_end=-19, method='cut_from_end' )
sflist = np.array( list(sflistd.values()) )
sflist
# Out:
# SD_C2_IEC3_Annealed_117
# array(['SD_C2_IEC3_Annealed_117_pos1_4999.7s_RH0.442_th0.050_15.00s_37712_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_5018.0s_RH0.437_th0.080_15.00s_37713_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_5036.0s_RH0.426_th0.100_15.00s_37714_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_5054.0s_RH0.437_th0.120_15.00s_37715_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_5073.0s_RH0.442_th0.150_15.00s_37716_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_5092.0s_RH0.416_th0.200_15.00s_37717_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_5111.0s_RH0.453_th0.250_15.00s_37718_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_11361.3s_RH22.237_th0.050_15.00s_37964_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_11379.5s_RH22.253_th0.080_15.00s_37965_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_11397.5s_RH22.280_th0.100_15.00s_37966_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_11415.5s_RH22.290_th0.120_15.00s_37967_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_11433.5s_RH22.275_th0.150_15.00s_37968_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_11451.5s_RH22.280_th0.200_15.00s_37969_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_11470.5s_RH22.312_th0.250_15.00s_37970_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_17697.8s_RH44.742_th0.050_15.00s_38216_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_17716.0s_RH44.737_th0.080_15.00s_38217_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_17734.0s_RH44.726_th0.100_15.00s_38218_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_17753.0s_RH44.716_th0.120_15.00s_38219_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_17771.0s_RH44.684_th0.150_15.00s_38220_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_17790.0s_RH44.716_th0.200_15.00s_38221_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_17809.0s_RH44.705_th0.250_15.00s_38222_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_24039.3s_RH69.803_th0.050_15.00s_38468_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_24057.5s_RH69.835_th0.080_15.00s_38469_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_24075.5s_RH69.835_th0.100_15.00s_38470_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_24093.5s_RH69.819_th0.120_15.00s_38471_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_24111.5s_RH69.808_th0.150_15.00s_38472_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_24129.5s_RH69.829_th0.200_15.00s_38473_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_24147.5s_RH69.819_th0.250_15.00s_38474_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_30379.7s_RH101.887_th0.050_15.00s_38720_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_30398.0s_RH101.887_th0.080_15.00s_38721_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_30417.0s_RH101.887_th0.100_15.00s_38722_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_30436.0s_RH101.877_th0.120_15.00s_38723_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_30455.0s_RH101.866_th0.150_15.00s_38724_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_30473.0s_RH101.872_th0.200_15.00s_38725_stitched_waxs.tiff',
#        'SD_C2_IEC3_Annealed_117_pos1_30491.0s_RH101.893_th0.250_15.00s_38726_stitched_waxs.tiff'],
#       dtype='<U87')

# %%
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/generic_functions.py

# %% [markdown]
# # A loop to sort

# %% [markdown]
# * here particularly for a humidity

# %%
humidity =np.array( [ 0, 25, 50, 75, 100  ] )
incs = np.array( [  0.05, 0.08, 0.10, 0.12, 0.15, 0.20, 0.25 ] )
#qYoneda = 4*np.pi/0.918 * np.deg2rad( [ (0.132 + incs)/2 ]  )
#print(qYoneda)

Nh = len( humidity)
Ni = len( incs )

# %%
ssam_dict = {}    
for sam in ks:     
    #print( 'The sample is: %s.'%sam)
    flist = np.sort( sam_dict[ sam ] )
    sflistd = sort_fnlist( flist, pattern='', cut_beg = -24, cut_end=-19, method='cut_from_end' )
    sflist = np.array( list(sflistd.values()) )
    sd = {}
    for i in range(Nh):
        sd[ str(humidity[i]) ] = sflist[ i *7 :  (1+i)*7   ]   
    ssam_dict[sam] =sd

# %%
#sd

# %% [markdown]
# # Load mask

# %%
#mask =np.load( '/home/yuzhang/NSLSII_Data_Link/CMS/2020_Cycle3/SWong/Mask/' + 'mask_saxs_2020C3_SWong.npy')
 
#mask1 =np.load( '/home/yuzhang/NSLSII_Data_Link/CMS/2020_Cycle3/Dishari/Mask/' + 'mask_waxs_2020C3_SD_noygap_run1.npy')
mask2 =np.load( '/home/yuzhang/NSLSII_Data_Link/CMS/2020_Cycle3/Dishari/Mask/' + 'mask_waxs_2020C3_Dishari_noygap.npy')
 

mask=mask2
show_img(mask)
# Out:
# <div id='149e0dca-3233-4a68-bf3f-4f4f460db4e3'></div>

# %% [markdown]
# ## Define parameters

# %%
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/Scattering.py

# %%
geometry   ='Reflection'
#geometry   = 'Transmission'
wav_m = 1E-10 * (12.398/  13.5 )
sdd_mm = 261.0 #273.9
b_xy = [   461, 1043  -  396 ] 
bs_xy = [ 0, 50]   
incident_angle = 0
det_str = 'Pilatus800' 
hotpixel_thres = 1e6
pargs_sc = dict( wav_m = wav_m, 
                sdd_mm = sdd_mm, 
                b_xy =b_xy, 
                bs_xy = bs_xy, 
                incident_angle = incident_angle,             
                det_str = det_str, 
                bs_kind = None, 
                useqx = True,
                geometry =  geometry,                
                username = username, # 'Fang', 
                cycle =  cycle, # ='2020_Cycle2',
                beamline = beamline, #'SMI',
                outDir = outDir, )
              # mask = mask )

# %%
# %matplotlib inline

# %%
#%matplotlib notebook

# %%
run_1st = ['SD_Bare_Si_Wafer',
 'SD_C2_IEC4_Annealed_20',
 'SD_C2_IEC4_Annealed_50',
 'SD_C2_IEC4_Annealed_70',
 'SD_C2_IEC4_Annealed_90',

 'SD_C2_IEC3_Annealed_117',
 'SD_C2_IEC3_Annealed_20',
 'SD_C2_IEC3_Annealed_55',
 'SD_C2_IEC3_Annealed_70',
 ]

# %% [markdown]
# # Do data reduction

# %%
T = True
F = False

# %%
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/generic_functions.py
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/Scattering.py
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/Scattering_Functions.py

# %%
outDir
# Out:
# '/home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/Results/'

# %%
do_plot = T #True 
do_plot_raw = F # True
#do_inpait = True, make it True, the circular average does not use inpaited data 
do_qimg = T
do_show_plot=T

###########################
#GiWAXS
###########################
do_ciravg = T #False  #True  

do_ciravg_sector = T #False  #True
#for the angle range,  h-right 0,  v-up is  90, l-left, ~ 180/-180;  v-down  ~90; 
ciravg_sector_angle_wid = 20 #this is a half width 
#ciravg_sector_angles = [  0, 90, 180, -90   ]
ciravg_sector_angles = [  20,   60,  100 , 140  ]

show_ciravg_sector = T


###########################
#for GiSAXS
###########################
do_linecut_qz = F #False #True
#qz_cuts= [0.04, 0.08, 0.15 ]
#qz_wid = 0.0025
show_linecut_qz = F # T
mark_Yon = F


##################
#for SAXS
####################
do_qphi = False  #True
do_stitch = False
do_q_qphi = False #True
do_p_qphi = False #True

# %%
sample_list = ks[:1]
sample_list = ks   #use a dummy papemill to run this

# %%
plt.ioff()
#plt.ion()

# %%
#loop all samples   
for sam in sample_list:  
#for sam in [  'SD_C2_IEC3_Annealed_117']:  #, 'SD_C2_IEC2_Unannealed_117',] : 
         
    print( 'The sample is: %s.'%sam)
    hum_inc_dict = ssam_dict[sam]
    hum_inc_dict_ks = list( hum_inc_dict.keys() ) 

    pargs_sc ['b_xy'] = b_xy    
    RES = {}   
    hi = 0 
    #loop all humidity
    for hum_key in  hum_inc_dict_ks[: ]:  
        hum =  humidity[hi] 
        RES['h=%s'%hum] = {}        
        inc_data_list = hum_inc_dict[ hum_key ]
        
        #loop all incident angles         
        for inc_data_fp in  inc_data_list[ :  ]: 
            SC=None
            p = re.search( 'th0\.', inc_data_fp  ).start()  +2
            inc =  inc_data_fp[p: p  + 4 ] 

            full_filenames = [ inDir +  inc_data_fp   ] 
            print('#'*40)
            print('The incident angle is: %s.'%inc) 
            print('The filename list for this sam=%s-inc=%s are:\n %s.'%(sam, inc, inc_data_fp )) 
            print('#'*40)
            
            N = len( full_filenames )       
            ## Setup the class
            pargs_sc ['incident_angle'] = float( inc )
            SC =  Scattering( pargs_sc  )   
            SC.md['sample'] = sam
            SC.create_ai()
            SC.load_data( full_filenames )
            #mask = SC.ai.mask_data  
            #mask_inp = np.zeros_like(mask)  
            RES['h=%s'%hum]['inc=%s'%inc] = {} 
            #RES['h=%s'%hum]['inc=%s'%inc]['raw'] = { }
            saved_plots = {}  
            saved_data = {}
            #SC.md['sid'] =  []
            #######################################
            #plot the raw data
            ########################################
            i = 0 #in this dataset, there is only one file
            sami = SC.md['filenames'][i]  
            sid = sami[ -24: -19]             
            SC.md['sid'] = sid
 
            if do_plot_raw:
                title='raw_%s'%(sami)
                fig, ax= plt.subplots()
                SC.plot_img( img=SC.imgs[i] * ~mask, title=title, vmin= None, vmax= None, save=True, 
                             fig_ax=[fig,ax],mask= ~mask, fontsize=6 )
                if not do_show_plot:
                    plt.close(fig)                
                saved_plots['raw'] = title + '.png'
                
            if do_qimg:
                title = 'qimg_%s'%(sami)
                qimg, qx, qz = SC.img_to_qimg( img = SC.imgs[i], bins=None, mask= mask, x='Qr', y='Qz', method = 'ai'  )
                #save to tiff?
                #save_array_to_tiff( qimg, SC.outDir + title 
                saved_plots['qimg'] = title + '.png'
                if do_plot:
                    fig, ax= plt.subplots()
                    SC.plot_qrz( img=qimg, x=qx, y=qz, fig_ax=[fig,ax], title=title, 
                                 fontsize=6, vmin=None, vmax=None  )
                    if mark_Yon:
                        ax.hlines( qYo, qx.min(),qx.max(), linewidth=1,color='r', linestyle = '--',    ) 
                    if not do_show_plot:
                        plt.close(fig)
                    plt.savefig( outDir + title + '.png' )                    
                qimg_mask = (qimg == 0)                    

            if do_linecut_qz:
                #Prange = [ [ qzi - qz_wid, qzi + qz_wid ] for qzi in qz_cuts  ]
                saved_data['lqz'] = []
                qz_cuts= [ qYo  ]
                qz_wid = 0.0025
                qiqs_lcqz = SC.qimg_linecut_qzs( qimg , qx_range=qx, qz_range=qz,
                                      qz_cuts=qz_cuts, qz_wid=qz_wid,  
                                       Qrange=[qx.min(), qx.max()], mask= ~qimg_mask  ) 
                
                title =  'waxs_linecut_qz_iqs_%s'%(sami)
                for kx in list( qiqs_lcqz.keys() ):                    
                    save_arrays(  data=qiqs_lcqz[kx], label= ['qr','qz=%s'%kx], dtype='array', 
                            filename=title+'_qz=%s.csv'%kx, path= SC.outDir, return_res = False,verbose=True) 
                    saved_data['lqz'].append( title+'_qz=%s.csv'%kx  )    
                saved_plots['lqz'] = title + '.png'                  
                if do_plot:    
                    fig, ax= plt.subplots()
                    SC.plot_stacked_multi_curves( xys = qiqs_lcqz, yshift = 1e2, save=True,fig_ax=[fig,ax],
                                          xlabel= r'$q_r(\AA^{-1})$', title =  title, fontsize=8 )
                    if not do_show_plot:
                        plt.close(fig)                    
                
                if do_plot:
                    if show_linecut_qz:                     
                        fig, ax = plt.subplots()
                        title='qimg_%s'%(sami)
                        SC.plot_qrz( img=qimg, x=qx, y=qz,title =  title , fontsize=6 , fig_ax = [fig,ax])
                        for qzc in qz_cuts:
                            plot1D( x= [ qx[0], qx[-1]] , y = [qzc, qzc], ls='-', ax =ax, 
                                   lw=1, m='',c ='r', legend='qz=%s'%qzc )
                        plt.savefig( SC.outDir + 'qimg_lincut_qz_%s'%(sami)) 
                        saved_plots['lqz'] = title + '.png'

            if do_ciravg:   
                Prange =  [0,180]
                Qrange =  None            
                q_ca,iq_ca, qmask_ca = SC.qimg_circular_average(qimg, qx, qz,
                                            Qrange=Qrange,Prange=Prange,bins=1500,mask= ~qimg_mask) 
                title =  'waxs_q_iq_%s'%(sami)
                save_arrays(  data= [q_ca, iq_ca], label= ['q_ca','iq_ca'], dtype='list', 
                            filename=title+'.csv', path= SC.outDir, return_res = False,verbose=True) 
                saved_data['qiq'] = title+'.csv'  
                
                if do_plot:                    
                    SC.plot_q_iq( q_ca,iq_ca, legend = 'ang_range-%s'%Prange,
                                 title =  title, figsize=[ 6,4  ], save=True , fontsize=6 ) 
                    saved_plots['qiq'] = title + '.png'

            if do_ciravg_sector: 
                saved_data['qiq_sec'] = []
                Prange =   [ [w-ciravg_sector_angle_wid, w+ciravg_sector_angle_wid] for w in  ciravg_sector_angles  ]
                Qrange =  None            
                title =  'waxs_qs_iqs_%s'%(sami)
                qiqs_cas,   qmask_cas = SC.qimg_circular_average_sector(qimg , qx, qz,
                                            Qrange=Qrange,Prange=Prange,bins=1500,mask= ~qimg_mask)                   
                for i, kx in enumerate(list( qiqs_cas.keys() )):    
                    a1,a2=Prange[i]
                    title_sub = title+'_qiq_angle=%s_%s.csv'%(a1,a2)
                    save_arrays(  data=qiqs_cas[kx], label= ['q','Iq-angle=%s_%s'%(a1,a2)], dtype='array', 
                            filename=title_sub,
                                path= SC.outDir, return_res = False,verbose=True) 
                    saved_data['qiq_sec'].append(  title_sub   )  
                     
                if do_plot:    
                    fig, ax= plt.subplots()
                    SC.plot_stacked_multi_curves( xys = qiqs_cas, yshift = 1e2, save=True,
                                                 legends= Prange, fig_ax=[fig,ax],
                                          xlabel= r'$q_r(\AA^{-1})$', title =  title, fontsize=8 )
                    if not do_show_plot:
                        plt.close(fig) 
                    
                saved_plots['qiq_sec'] = title + '.png'
                if show_ciravg_sector:
                    N = len(Prange)
                    fig,axes=create_fig_ax( H=1,V=N, figsize=[8,4],  y=1.08, title='ciravg_sector_cuts' )
                    for i, ki in enumerate(list(qmask_cas.keys())):
                        show_img( qmask_cas[ ki ], ax=[fig, axes[i]], image_name = Prange[i])
            if do_qphi:  
                qphi_bins = [ 500, 180 ]
                Prange =  None
                Qrange =  None            
                q_QP, phi_QP, qphi_QP, qphi_mask = SC.qimg_to_qphi(qimg, qx, qz,
                                                        Qrange=Qrange,Prange=Prange,                                                      
                                                          bins=qphi_bins,mask=qmask) 
                if do_q_qphi:
                    q_QPq,  iq_QPq = SC.qphi_to_iq( qphi_QP, q_range=q_QP, p_range=phi_QP, )
                if do_p_qphi:  
                    p_QPp,  ip_QPp = SC.qphi_to_ip( qphi_QP, q_range=q_QP, p_range=phi_QP, )            
                if do_plot:
                    title = 'qphi_%s'%sami
                    SC.plot_qphi( qphi_QP, q_QP, phi_QP, vmin= None,
                                  vmax=None, aspect= 0.0005,
                                  title= title , save=True, fontsize=6 ) 
                    saved_plots['qphi'] = title + '.png'
            res = SC.res_to_dict( do_ciravg =do_ciravg, do_qphi = do_qphi, do_qimg=do_qimg,
                                 do_q_qphi = do_q_qphi, do_p_qphi = do_p_qphi,
                                 do_linecut_qz = do_linecut_qz,  
                                 do_ciravg_sector = do_ciravg_sector )
            res['md'] = {} 
            res['md'].update( SC.md   )
            RES['h=%s'%hum]['inc=%s'%inc]  = res  
            RES['h=%s'%hum]['inc=%s'%inc]['saved_plots'] = saved_plots 
            RES['h=%s'%hum]['inc=%s'%inc]['saved_data'] = saved_data             
            #print(  'h=%s'%hum,  'inc=%s'%inc )
            #print('the meta data should be:')
            #print(  RES['h=%s'%hum]['inc=%s'%inc]['md'] )
            #print( SC.md)
            #RES['h=%s'%hum]['inc=%s'%inc]['mask'] = mask
        hi += 1
    dicttoh5( RES, os.path.join(outDir_HDF, '%s.h5'%sam),
                             h5path='/GiWAXS/', mode='a', overwrite_data=True)

    print('Done')
# Out:
# The sample is: SD_Bare_Si_Wafer.
# ########################################
# The incident angle is: 0.05.
# The filename list for this sam=SD_Bare_Si_Wafer-inc=0.05 are:
#  SD_Bare_Si_Wafer_pos1_6428.7s_RH0.410_th0.050_15.00s_37782_stitched_waxs.tiff.
# ########################################
# The file: waxs_q_iq_SD_Bare_Si_Wafer_pos1_6428.7s_RH0.410_th0.050_15.00s_37782_stitched_waxs.tiff.csv is saved in /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/Results/
# /home/group/Software/pyScatt/pyScatt/plots.py:66: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   axes.append( fig.add_subplot(H,V,i+1)    )
# The file: waxs_qs_iqs_SD_Bare_Si_Wafer_pos1_6428.7s_RH0.410_th0.050_15.00s_37782_stitched_waxs.tiff_qiq_angle=0_40.csv is saved in /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/Results/
# The file: waxs_qs_iqs_SD_Bare_Si_Wafer_pos1_6428.7s_RH0.410_th0.050_15.00s_37782_stitched_waxs.tiff_qiq_angle=40_80.csv is saved in /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/Results/
# The file: waxs_qs_iqs_SD_Bare_Si_Wafer_pos1_6428.7s_RH0.410_th0.050_15.00s_37782_stitched_waxs.tiff_qiq_angle=80_120.csv is saved in /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/Results/
# The file: waxs_qs_iqs_SD_Bare_Si_Wafer_pos1_6428.7s_RH0.410_th0.050_15.00s_37782_stitched_waxs.tiff_qiq_angle=120_160.csv is saved in /home/group/NSLSII_Data/CMS/2020_Cycle3/Dishari/Results/Dishari/WAXS/Results/
# Done

# %% [markdown]
# # The END!

# %%
if F:
    fig, ax = plt.subplots()
    qimgc = qimg.copy()
    rc = 630
    ring_mask = create_ring_mask( qimg.shape, r1=rc-10, r2=rc+10, center = [450, 186 ]  )
    qimgc[ring_mask] *=1e3


    SC.plot_img( img=qimgc, title='qimg_%s'%(sami), fontsize=6 , fig_ax = [fig,ax])
    #SC.plot_qrz( img=qimg, x=qx, y=qz, title='qimg_%s'%(sami), fontsize=6 , fig_ax = [fig,ax])
