# %% [markdown]
# # Template of a SMI jupyter notebook

# %%
if True:
    #%matplotlib notebook
    from pyScatt.packages import *
    plt.rcParams.update({'figure.max_open_warning': 0})
    plt.rcParams.update({ 'image.origin': 'lower'   })
    plt.rcParams.update({ 'image.interpolation': 'none'   })
    import re
    T=True
    F=False
    #%matplotlib notebook
    create_ds_args = {'compression': "gzip", 'shuffle': True,  'fletcher32': True}
# Out:
# WARNING:silx.opencl.common:The module pyOpenCL has been imported but can't be used here

# %%
if False:
    import sys, os
    SciAnalysis_PATH='/home/yuzhang/Repos/SciAnalysis/'
    SciAnalysis_PATH in sys.path or sys.path.append(SciAnalysis_PATH)
    from SciAnalysis.IO_HDF import dicttoh5, h5todict

# %%
import glob
# %run -i  /home/group/Software/SciAnalysis/SciAnalysis/XSAnalysis/Protocols.py
# %run -i  /home/group/Software/SciAnalysis/SciAnalysis/XSAnalysis/Data.py
# %run -i  /home/group/Software/SciAnalysis/SciAnalysis/tools.py

# %%
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/generic_functions.py
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/IO.py
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/saxs.py

# %run -i /home/yuzhang/Software/pyScatt/pyScatt/plots.py

# %% [markdown]
# ## Locate the files on your computer

# %%
username = 'FL' 
 

inDir = '/home/group/NSLSII_Data/CMS/2021_Cycle1/Fang/HDF_Results/'#%( username ) 
outDir0 = '/home/group/NSLSII_Data/CMS/2021_Cycle1/Fang/PostAnalysis/'#%( username ) 


outDir = create_fullpath(  outDir0 )
# Out:
# Directory  /home/group/NSLSII_Data/CMS/2021_Cycle1/Fang/PostAnalysis/  already exists

# %%
#outDir = '/home/yuzhang/XScattering/Fang_Project/Etching/Data/'

# %% [markdown]
# ## Get the filename list for this user-

# %%
t_list = sorted( ls_dir( inDir, and_list=[ username, 'OC' ]) )

print( t_list)
# Out:
# ['FL_Mar19_OC_000h.h5', 'FL_Mar19_OC_002h.h5', 'FL_Mar19_OC_006h.h5', 'FL_Mar19_OC_017h.h5', 'FL_Mar19_OC_028h.h5', 'FL_Mar19_OC_039h.h5', 'FL_Mar19_OC_050h.h5', 'FL_Mar19_OC_065h.h5', 'FL_Mar19_OC_080h.h5', 'FL_Mar19_OC_100h.h5', 'FL_Mar19_OC_120h.h5']

# %%
print( t_list )
# Out:
# ['FL_Mar19_OC_000h.h5', 'FL_Mar19_OC_002h.h5', 'FL_Mar19_OC_006h.h5', 'FL_Mar19_OC_017h.h5', 'FL_Mar19_OC_028h.h5', 'FL_Mar19_OC_039h.h5', 'FL_Mar19_OC_050h.h5', 'FL_Mar19_OC_065h.h5', 'FL_Mar19_OC_080h.h5', 'FL_Mar19_OC_100h.h5', 'FL_Mar19_OC_120h.h5']

# %%
#%matplotlib inline

# %%
t_list
# Out:
# ['FL_Mar19_OC_000h.h5',
#  'FL_Mar19_OC_002h.h5',
#  'FL_Mar19_OC_006h.h5',
#  'FL_Mar19_OC_017h.h5',
#  'FL_Mar19_OC_028h.h5',
#  'FL_Mar19_OC_039h.h5',
#  'FL_Mar19_OC_050h.h5',
#  'FL_Mar19_OC_065h.h5',
#  'FL_Mar19_OC_080h.h5',
#  'FL_Mar19_OC_100h.h5',
#  'FL_Mar19_OC_120h.h5']

# %%
# %matplotlib notebook

# %% [markdown]
# ## pull out the saxs data and sort out by timing

# %%
Q = {}
IQ = {}

# %%
t_list
# Out:
# ['FL_Mar19_OC_000h.h5',
#  'FL_Mar19_OC_002h.h5',
#  'FL_Mar19_OC_006h.h5',
#  'FL_Mar19_OC_017h.h5',
#  'FL_Mar19_OC_028h.h5',
#  'FL_Mar19_OC_039h.h5',
#  'FL_Mar19_OC_050h.h5',
#  'FL_Mar19_OC_065h.h5',
#  'FL_Mar19_OC_080h.h5',
#  'FL_Mar19_OC_100h.h5',
#  'FL_Mar19_OC_120h.h5']

# %%
samk = 'FL_Mar19_OC_000h.h5'

samk = t_list[     10       ]
print(samk)
# Out:
# FL_Mar19_OC_120h.h5

# %% [markdown]
# # WAXS

# %%
RES = h5todict( inDir + samk  )
KEYS = list( RES.keys() )
print(RES['WAXS'].keys() )
print('The filenames are:%s'%RES['WAXS'][  'md'][ 'filenames' ] )


fps = RES['WAXS'][  'md'][ 'filenames' ]
#sids = RES['SAXS'][  'md'][ 'sid' ]
N = len( fps )
fig, ax = plt.subplots()
for i in range( N ):    
    #sid = sids[i]
    fp = fps[i]
    print(i,  fp )
    d = RES['WAXS']['Data'][fp]['cir_avg']['data']
    q,iq = d[:,0],d[:,1]          
    plot1D( x=q, y = iq, m=markers[i], c=colors[i], ax = ax, ls = '-', markersize=1, 
            #xlim=[0.003,0.148], logx=True,
            logy=True, legend=str(i)+'--'+ fp[6:-10], legend_size=6 )

    if i == 6:
        IQ[samk[:-3]]  = iq
        print('Use this data:%s--%s in the fininal DA.'%(i,fp) )
# Out:
# dict_keys(['Data', 'md', 'raw_data'])
# The filenames are:['FL_Mar19_OC_120h_310.2s_x0.000_y0.000_1.00s_272909_waxs.tiff'
#  'FL_Mar19_OC_120h_346.0s_x0.000_y0.000_1.00s_272910_waxs.tiff'
#  'FL_Mar19_OC_120h_394.2s_x0.000_y0.000_1.00s_272911_waxs.tiff'
#  'FL_Mar19_OC_120h_439.1s_x0.000_y0.000_1.00s_272912_waxs.tiff'
#  'FL_Mar19_OC_120h_527.1s_x0.000_y0.000_1.00s_272913_waxs.tiff'
#  'FL_Mar19_OC_120h_538.4s_x0.000_y-0.300_1.00s_272914_waxs.tiff'
#  'FL_Mar19_OC_120h_562.9s_x0.000_y0.000_10.00s_272915_waxs.tiff']
# <img src="data:image/png;base64,..." width="640">
# 0 FL_Mar19_OC_120h_310.2s_x0.000_y0.000_1.00s_272909_waxs.tiff
# 1 FL_Mar19_OC_120h_346.0s_x0.000_y0.000_1.00s_272910_waxs.tiff
# 2 FL_Mar19_OC_120h_394.2s_x0.000_y0.000_1.00s_272911_waxs.tiff
# 3 FL_Mar19_OC_120h_439.1s_x0.000_y0.000_1.00s_272912_waxs.tiff
# 4 FL_Mar19_OC_120h_527.1s_x0.000_y0.000_1.00s_272913_waxs.tiff
# 5 FL_Mar19_OC_120h_538.4s_x0.000_y-0.300_1.00s_272914_waxs.tiff
# ...

# %%
IQ.keys()
# Out:
# dict_keys(['FL_Mar19_OC_000h', 'FL_Mar19_OC_002h', 'FL_Mar19_OC_006h', 'FL_Mar19_OC_017h', 'FL_Mar19_OC_028h', 'FL_Mar19_OC_039h', 'FL_Mar19_OC_050h', 'FL_Mar19_OC_065h', 'FL_Mar19_OC_080h', 'FL_Mar19_OC_100h', 'FL_Mar19_OC_120h'])

# %% [markdown]
# # SAXS

# %%
RES = h5todict( inDir + samk  )
KEYS = list( RES.keys() )
print(RES['SAXS'].keys() )
print('The filenames are:%s'%RES['SAXS'][  'md'][ 'filenames' ] )


fps = RES['SAXS'][  'md'][ 'filenames' ]
#sids = RES['SAXS'][  'md'][ 'sid' ]
N = len( fps )
fig, ax = plt.subplots()
for i in range( N ):    
    #sid = sids[i]
    fp = fps[i]
    print(i,  fp )
    d = RES['SAXS']['Data'][fp]['cir_avg']['data']
    q,iq = d[:,0],d[:,1]          
    plot1D( x=q, y = iq, m=markers[i], c=colors[i], ax = ax, ls = '-', markersize=1, 
            xlim=[0.003,0.148], logx=True,
            logy=True, legend=str(i)+'--'+ fp[6:-10], legend_size=6 )

    if i == 2:
        IQ[samk[:-3]]  = iq
# Out:
# dict_keys(['Data', 'md', 'raw_data'])
# The filenames are:['FL_Mar19_OC_050h_719.3s_x0.000_y0.000_1.00s_272919_saxs.tiff'
#  'FL_Mar19_OC_050h_730.7s_x0.000_y0.000_10.00s_272920_saxs.tiff'
#  'FL_Mar19_OC_050h_757.9s_x0.000_y-0.200_10.00s_272921_saxs.tiff']
# <img src="data:image/png;base64,..." width="640">
# 0 FL_Mar19_OC_050h_719.3s_x0.000_y0.000_1.00s_272919_saxs.tiff
# 1 FL_Mar19_OC_050h_730.7s_x0.000_y0.000_10.00s_272920_saxs.tiff
# 2 FL_Mar19_OC_050h_757.9s_x0.000_y-0.200_10.00s_272921_saxs.tiff

# %%
IQ.keys()
# Out:
# dict_keys(['FL_Mar19_OC_000h', 'FL_Mar19_OC_002h', 'FL_Mar19_OC_006h', 'FL_Mar19_OC_017h', 'FL_Mar19_OC_028h', 'FL_Mar19_OC_039h', 'FL_Mar19_OC_050h', 'FL_Mar19_OC_065h', 'FL_Mar19_OC_080h', 'FL_Mar19_OC_100h', 'FL_Mar19_OC_120h'])

# %% [markdown]
# # Put all data together

# %%
Q=q

# %%
# fp = 'Cir_Avg__FL_OC4_x39494.76_y-4799.97_waxsP65.00_expt1s_attNone_sid00135937_000001_SAXS.tif.csv'
# inD = '/home/yuzhang/NSLSII_Data_Link/SMI/2020_Cycle3/308052_Zhang/Results/Test/SAXS/Cir_Avg/'
# d = pds.read_csv( inD + fp )
# qx,iqx = np.array(d['q_ca']), np.array(d['iq_ca'])
# iqxp = np.interp( Q, qx, iqx)
# IQ['99h_135937_inf'] = iqxp

# %%
 Q.shape, len( IQ.keys() )
# Out:
# ((1500,), 11)

# %%
QIQ = np.zeros( [ Q.shape[0], len( IQ.keys()) + 1 ])
des = ['q'] + sorted(  list( IQ.keys() )   )
i=1
QIQ[:,0] = Q
for k in des[1:]:
    print( k )
    QIQ[:,i] = IQ[k]
    i+=1
# Out:
# FL_Mar19_OC_000h
# FL_Mar19_OC_002h
# FL_Mar19_OC_006h
# FL_Mar19_OC_017h
# FL_Mar19_OC_028h
# FL_Mar19_OC_039h
# FL_Mar19_OC_050h
# FL_Mar19_OC_065h
# FL_Mar19_OC_080h
# FL_Mar19_OC_100h
# FL_Mar19_OC_120h

# %%
outDir
# Out:
# '/home/group/NSLSII_Data/CMS/2021_Cycle1/Fang/PostAnalysis/'

# %%
#save_arrays( QIQ, label = des, filename='Octo_Systems_2021CMSC1.csv', path = outDir, verbose=True, return_res=True )
save_arrays( QIQ, label = des, filename='Octo_Systems_2021CMSC1_WAXS.csv', path = outDir, verbose=True, return_res=True )
# Out:
# The file: Octo_Systems_2021CMSC1_WAXS.csv is saved in /home/group/NSLSII_Data/CMS/2021_Cycle1/Fang/PostAnalysis/
#              q  FL_Mar19_OC_000h  FL_Mar19_OC_002h  FL_Mar19_OC_006h  \
# 0     0.608398       1398.734497       1433.773804       1413.198486
# 1     0.610535       1398.511963       1441.327148       1412.299561
# 2     0.612671       1393.269165       1424.125122       1396.758301
# 3     0.614808       1395.119263       1419.065674       1394.574585
# 4     0.616945       1399.370483       1427.473755       1406.131836
# ...        ...               ...               ...               ...
# 1495  3.802714        362.781342        216.083771        201.100296
# 1496  3.804851        354.819305        219.919647        205.693695
# 1497  3.806987        351.216064        215.652328        205.665924
# 1498  3.809124        351.046326        212.629166        192.295380
# 1499  3.811261        359.157410        208.104202        185.277573
#
# ...

# %% [markdown]
# # Plot again

# %%
fig, ax = plt.subplots()
for i in range( 1,  QIQ.shape[1]     ):        
    plot1D( x=Q, y = QIQ[:,i], m=markers[i], c=colors[i+1], ax = ax, ls = '-', markersize=4, 
            logy=True, legend= des[i], legend_size=6, logx=True )#, xlim=[0.003,0.148])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
QIQ.shape
# Out:
# (1500, 12)

# %%
fig, ax = plt.subplots()
for i in [1,11]:        
    plot1D( x=Q, y = QIQ[:,i], m=markers[i], c=colors[i+1], ax = ax, ls = '-', markersize=2, 
            logy=True, legend= des[i], legend_size=6, logx=True , xlim=[0.003,0.148], )
          #ylim=[2,1e3])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#IQ.pop('27h_115112' )
