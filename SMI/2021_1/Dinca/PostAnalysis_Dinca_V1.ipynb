# %%
# %matplotlib notebook
from pyScatt.packages import *
plt.rcParams.update({'figure.max_open_warning': 0})
plt.rcParams.update({ 'image.origin': 'lower'   })
plt.rcParams.update({ 'image.interpolation': 'none'   })
T = True
F = False
# Out:
# WARNING:silx.opencl.common:The module pyOpenCL has been imported but can't be used here

# %%
inDir = '/home/yuzhang/NSLSII_Data_Link/SMI/2021_Cycle1/308052_Dinca/Results/HDF_Results/'

outDir = '/home/yuzhang/NSLSII_Data_Link/SMI/2021_Cycle1/308052_Dinca/Results/' + 'PostAnalys'
outDir = create_fullpath(  outDir )
# Out:
# The Directory  /home/yuzhang/NSLSII_Data_Link/SMI/2021_Cycle1/308052_Dinca/Results/PostAnalys  is created.

# %%
ls_dir( inDir )
# Out:
# array(['_Dinca_Zn_PDI.h5', '_Dinca_Mn_PDI.h5', '_Dinca_PDI_Ligand.h5',
#        '_Dinca_RW_1315.h5', '_Dinca_Zn_PDI_2.h5', '_Dinca_Mn_PDI_32.h5',
#        '_Dinca_NiBHT.h5', '_Dinca_NiBHT_Neg.h5', '_Dinca_NiBHT_Pos.h5',
#        '_Dinca_TIBQ_COF_DMA.h5', '_Dinca_TIBA_COF_CTAB.h5'], dtype='<U23')

# %%
sams = ['_Dinca_Zn_PDI.h5', '_Dinca_Mn_PDI.h5', '_Dinca_PDI_Ligand.h5',
       '_Dinca_RW_1315.h5', '_Dinca_Zn_PDI_2.h5', '_Dinca_Mn_PDI_32.h5',
       '_Dinca_NiBHT.h5', '_Dinca_NiBHT_Neg.h5', '_Dinca_NiBHT_Pos.h5',
       '_Dinca_TIBQ_COF_DMA.h5', '_Dinca_TIBA_COF_CTAB.h5']
sam = sams[0]

# %%
def _get_saxs():
    qiq_dict = {}
    for sam in sams:
        Res = h5todict( inDir + sam  )['SAXS']
        fps = Res['md']['filenames']
        fp = fps[0]
        print( fp )
        qiq_dict[ sam ] =Res[fp]['cir_avg']['data']
    return qiq_dict    
        
def _get_waxs():
    qiq_dict = {}
    for sam in sams:
        Res = h5todict( inDir + sam  )['WAXS']
        #fps = Res['md']['filenames']
        #fp = fps[0]
        #print( fp )
        qiq_dict[ sam ] =Res['cir_avg']['data']   
    return qiq_dict

# %%
qiqs = _get_saxs()
qiqw = _get_waxs()
# Out:
# _Dinca_Zn_PDI_x-17999.95_y-5019.77_det5000.0m_expt0.1s_attNone_sid00268287_000001_SAXS.tif
# _Dinca_Mn_PDI_x-11600.03_y-5019.9_det5000.0m_expt0.1s_attNone_sid00268288_000001_SAXS.tif
# _Dinca_PDI_Ligand_x-5400.0_y-5019.9_det5000.0m_expt0.1s_attNone_sid00268289_000001_SAXS.tif
# _Dinca_RW_1315_x1100.0_y-5019.89_det5000.0m_expt0.1s_attNone_sid00268290_000001_SAXS.tif
# _Dinca_Zn_PDI_2_x7600.0_y-5019.9_det5000.0m_expt0.1s_attNone_sid00268291_000001_SAXS.tif
# _Dinca_Mn_PDI_32_x13900.0_y-5019.9_det5000.0m_expt0.1s_attNone_sid00268292_000001_SAXS.tif
# _Dinca_NiBHT_x20200.0_y-5019.9_det5000.0m_expt0.1s_attNone_sid00268293_000001_SAXS.tif
# _Dinca_NiBHT_Neg_x26500.0_y-5019.9_det5000.0m_expt0.1s_attNone_sid00268294_000001_SAXS.tif
# _Dinca_NiBHT_Pos_x32799.99_y-5019.9_det5000.0m_expt0.1s_attNone_sid00268295_000001_SAXS.tif
# _Dinca_TIBQ_COF_DMA_x39200.0_y-5019.9_det5000.0m_expt0.1s_attNone_sid00268296_000001_SAXS.tif
# _Dinca_TIBA_COF_CTAB_x45400.0_y-5019.89_det5000.0m_expt0.1s_attNone_sid00268297_000001_SAXS.tif

# %%
sams
# Out:
# ['_Dinca_Zn_PDI.h5',
#  '_Dinca_Mn_PDI.h5',
#  '_Dinca_PDI_Ligand.h5',
#  '_Dinca_RW_1315.h5',
#  '_Dinca_Zn_PDI_2.h5',
#  '_Dinca_Mn_PDI_32.h5',
#  '_Dinca_NiBHT.h5',
#  '_Dinca_NiBHT_Neg.h5',
#  '_Dinca_NiBHT_Pos.h5',
#  '_Dinca_TIBQ_COF_DMA.h5',
#  '_Dinca_TIBA_COF_CTAB.h5']

# %%
# %run -i /home/yuzhang/Software/pyScatt/pyScatt/users_temp.py

# %% [markdown]
# ## Plot WAXS together

# %%
fig,axes=create_fig_ax( H=1,V=1, figsize=[8,6], title='',fontsize=12, y=1.08  ) 

i=0
#for sam in [  sams[0], sams[1]  ]:
for sam in sams:    
    ca = qiqw[sam]
    q, iq = ca[:,0], ca[:,1] + i #*1e3

    ax = axes[0]   
    plot1D( x= q, y= iq  , m= markers[i], ls='-', ax=ax, c=colors[i], markersize=1,
        logy=True, logx= False, 
        title='circular average-WAXS', 
       legend='sam=%s'%sam[7:], fontsize=16, tick_size =18, 
       xlabel=r'$Q (\AA^{-1})$', ylabel= r'$Intensity (a.u.)$', )
    
    xm,ym =  find_max_peak( q, iq , xrange=[0.2, 0.4 ])
    La = get_La( xm )
    qs = get_2dhx_qs( m = 8, a = La )
    print(qs[0], qs[-1], La)
    
    #ax.set_xlim([0.12, 4 ])   
    #ax.set_ylim([  1e4, ym*5.0])
    if i ==100:
        ax.vlines( qs, 0, ym*5 , label=r'$2D\ hexagonal\ L_a=%.2f\ nm$'%(La), 
                  linestyle='-' , linewidth=.5  )
  
    
    
    i += 1
ax.legend(loc = 'best', fontsize= 12 )
ax.set_ylabel( r'$Intensity (a.u.)$', fontsize=18)
ax.set_xlabel( r'$Q (\AA^{-1})$', fontsize=18)
# Out:
# <img src="data:image/png;base64,..." width="800">
# /home/group/Software/pyScatt/pyScatt/plots.py:91: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   axes.append( fig.add_subplot(H,V,i+1)    )
# 0.2857640466037854 3.4647049338596574 25.388769312174084
# 0.27311118631758396 3.3112971557222575 26.56499557839515
# 0.30263452698538734 3.669248638042857 23.97346241094027
# 0.39542216908419786 4.794239011050454 18.347978500396145
# 0.2857640466037854 3.4647049338596574 25.388769312174084
# 0.20141164469577585 2.4419864129436606 36.021737809129924
# 0.20141164469577585 2.4419864129436606 36.021737809129924
# 0.20141164469577585 2.4419864129436606 36.021737809129924
# 0.20141164469577585 2.4419864129436606 36.021737809129924
# 0.20141164469577585 2.4419864129436606 36.021737809129924
# 0.20141164469577585 2.4419864129436606 36.021737809129924
# Text(0.5, 0, '$Q (\\AA^{-1})$')

# %% [markdown]
# # Plot SAXS together

# %%
fig,axes=create_fig_ax( H=1,V=1, figsize=[8,6], title='',fontsize=12, y=1.08  ) 

i=0
for sam in sams:
    ca = qiqs[sam]
    q, iq = ca[:,0], ca[:,1]  

    ax = axes[0]   
    plot1D( x= q, y= iq  , m= markers[i], ls='', ax=ax, c=colors[i], markersize=3,
        logy=True, logx= True, 
        title='circular average-SAXS', 
       legend='sam=%s'%sam[7:], fontsize=16, tick_size =18, 
       xlabel=r'$Q (\AA^{-1})$', ylabel= r'$Intensity (a.u.)$', )
 
    
    #ax.set_xlim([0.12, 4 ])   
    #ax.set_ylim([  1e4, ym*5.0])    
    i += 1
ax.legend(loc = 'best', fontsize= 12 )
ax.set_ylabel( r'$Intensity (a.u.)$', fontsize=18)
ax.set_xlabel( r'$Q (\AA^{-1})$', fontsize=18)
# Out:
# <img src="data:image/png;base64,..." width="800">
# /home/group/Software/pyScatt/pyScatt/plots.py:91: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   axes.append( fig.add_subplot(H,V,i+1)    )
# Text(0.5, 0, '$Q (\\AA^{-1})$')
